# %% [markdown]
# ## Loading The Dataset
#
# ##### 1.We can also read the dataset from csv
# ##### 2.then convert to datatable

# %%
import evalml
X, y = evalml.demos.load_breast_cancer()
X_train, X_test, y_train, y_test = evalml.preprocessing.split_data(X, y, problem_type='binary')

# %%
X_train.head()
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 381        11.04         14.93           70.67      372.7          0.07987
# 144        10.75         14.97           68.26      355.3          0.07793
# 136        11.71         16.67           74.72      423.6          0.10510
# 116         8.95         15.76           58.74      245.2          0.09462
# 567        20.60         29.33          140.10     1265.0          0.11780
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 381           0.07079         0.03546             0.020740         0.2003
# 144           0.05139         0.02251             0.007875         0.1399
# 136           0.06095         0.03592             0.026000         0.1339
# 116           0.12430         0.09263             0.023080         0.1305
# 567           0.27700         0.35140             0.152000         0.2397
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# 381                 0.06246  ...        12.090          20.83
# 144                 0.05688  ...        11.950          20.72
# 136                 0.05945  ...        13.330          25.48
# 116                 0.07163  ...         9.414          17.07
# 567                 0.07016  ...        25.740          39.42
#
#      worst perimeter  worst area  worst smoothness  worst compactness  \
# 381            79.73       447.1            0.1095             0.1982
# 144            77.79       441.2            0.1076             0.1223
# 136            86.16       546.7            0.1271             0.1028
# 116            63.34       270.0            0.1179             0.1879
# 567           184.60      1821.0            0.1650             0.8681
#
#      worst concavity  worst concave points  worst symmetry  \
# 381          0.15530               0.06754          0.3202
# 144          0.09755               0.03413          0.2300
# 136          0.10460               0.06968          0.1712
# 116          0.15440               0.03846          0.1652
# 567          0.93870               0.26500          0.4087
#
#      worst fractal dimension
# 381                  0.07287
# 144                  0.06769
# 136                  0.07343
# 116                  0.07722
# 567                  0.12400
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Running the AutoML to select the best algorithm

# %%
import evalml
evalml.problem_types.ProblemTypes.all_problem_types
# Out:
# [<ProblemTypes.BINARY: 'binary'>,
#  <ProblemTypes.MULTICLASS: 'multiclass'>,
#  <ProblemTypes.REGRESSION: 'regression'>,
#  <ProblemTypes.TIME_SERIES_REGRESSION: 'time series regression'>,
#  <ProblemTypes.TIME_SERIES_BINARY: 'time series binary'>,
#  <ProblemTypes.TIME_SERIES_MULTICLASS: 'time series multiclass'>]

# %%
from evalml.automl import AutoMLSearch
automl = AutoMLSearch(X_train=X_train, y_train=y_train, problem_type='binary')
automl.search()
# Out:
# Using default limit of max_batches=1.
#
# Generating pipelines to search over...
# 8 pipelines ready for search.
#
# *****************************
# * Beginning pipeline search *
# *****************************
#
# Optimizing for Log Loss Binary.
# Lower score is better.
#
# Using SequentialEngine to train and score pipelines.
# Searching up to 1 batches for a total of 9 pipelines.
# Allowed model families: decision_tree, linear_model, xgboost, extra_trees, catboost, random_forest, lightgbm
# FigureWidget({
#     'data': [{'mode': 'lines+markers',
#               'name': 'Best Score',
#               'type'…
# Evaluating Baseline Pipeline: Mode Baseline Binary Classification Pipeline
# Mode Baseline Binary Classification Pipeline:
# 	Starting cross validation
# 	Finished cross validation - mean Log Loss Binary: 12.904
#
# *****************************
# * Evaluating Batch Number 1 *
# *****************************
#
# Elastic Net Classifier w/ Imputer + Standard Scaler:
# 	Starting cross validation
# 	Finished cross validation - mean Log Loss Binary: 0.672
# 	High coefficient of variation (cv >= 0.2) within cross validation scores.
# 	Elastic Net Classifier w/ Imputer + Standard Scaler may not perform as estimated on unseen data.
# Decision Tree Classifier w/ Imputer:
# 	Starting cross validation
# 	Finished cross validation - mean Log Loss Binary: 2.432
# 	High coefficient of variation (cv >= 0.2) within cross validation scores.
# 	Decision Tree Classifier w/ Imputer may not perform as estimated on unseen data.
# Random Forest Classifier w/ Imputer:
# 	Starting cross validation
# 	Finished cross validation - mean Log Loss Binary: 0.120
# LightGBM Classifier w/ Imputer:
# 	Starting cross validation
# 	Finished cross validation - mean Log Loss Binary: 0.133
# Logistic Regression Classifier w/ Imputer + Standard Scaler:
# 	Starting cross validation
# 	Finished cross validation - mean Log Loss Binary: 0.094
# 	High coefficient of variation (cv >= 0.2) within cross validation scores.
# 	Logistic Regression Classifier w/ Imputer + Standard Scaler may not perform as estimated on unseen data.
# XGBoost Classifier w/ Imputer:
# 	Starting cross validation
# 	Finished cross validation - mean Log Loss Binary: 0.113
# 	High coefficient of variation (cv >= 0.2) within cross validation scores.
# 	XGBoost Classifier w/ Imputer may not perform as estimated on unseen data.
# Extra Trees Classifier w/ Imputer:
# 	Starting cross validation
# 	Finished cross validation - mean Log Loss Binary: 0.137
# CatBoost Classifier w/ Imputer:
# 	Starting cross validation
# 	Finished cross validation - mean Log Loss Binary: 0.386
#
# Search finished after 01:15
# Best pipeline: Logistic Regression Classifier w/ Imputer + Standard Scaler
# Best pipeline Log Loss Binary: 0.094015

# %%
automl.rankings
# Out:
#    id                                      pipeline_name  mean_cv_score  \
# 0   5  Logistic Regression Classifier w/ Imputer + St...       0.094015
# 1   6                      XGBoost Classifier w/ Imputer       0.113098
# 2   3                Random Forest Classifier w/ Imputer       0.119972
# 3   4                     LightGBM Classifier w/ Imputer       0.132722
# 4   7                  Extra Trees Classifier w/ Imputer       0.136959
# 5   8                     CatBoost Classifier w/ Imputer       0.386387
# 6   1  Elastic Net Classifier w/ Imputer + Standard S...       0.672286
# 7   2                Decision Tree Classifier w/ Imputer       2.431916
# 8   0       Mode Baseline Binary Classification Pipeline      12.904388
#
#    standard_deviation_cv_score  validation_score  \
# 0                     0.033791          0.060529
# 1                     0.038613          0.069048
# 2                     0.019487          0.099614
# 3                     0.024842          0.110679
# 4                     0.022862          0.111169
# 5                     0.011583          0.374338
# 6                     0.178662          0.501981
# 7                     0.531935          2.726782
# 8                     0.082537         12.952041
#
#    percent_better_than_baseline  high_variance_cv  \
# 0                     99.271446              True
# 1                     99.123568              True
# 2                     99.070299             False
# 3                     98.971496             False
# 4                     98.938661             False
# 5                     97.005774             False
# 6                     94.790251              True
# 7                     81.154350              True
# 8                      0.000000             False
#
#                                           parameters
# 0  {'Imputer': {'categorical_impute_strategy': 'm...
# 1  {'Imputer': {'categorical_impute_strategy': 'm...
# 2  {'Imputer': {'categorical_impute_strategy': 'm...
# 3  {'Imputer': {'categorical_impute_strategy': 'm...
# 4  {'Imputer': {'categorical_impute_strategy': 'm...
# 5  {'Imputer': {'categorical_impute_strategy': 'm...
# 6  {'Imputer': {'categorical_impute_strategy': 'm...
# 7  {'Imputer': {'categorical_impute_strategy': 'm...
# 8      {'Baseline Classifier': {'strategy': 'mode'}}

# %% [markdown]
# ## Getting The Best Pipeline

# %%
automl.best_pipeline
# Out:
# pipeline = BinaryClassificationPipeline(component_graph=[Imputer, StandardScaler, LogisticRegressionClassifier], parameters={'Imputer':{'categorical_impute_strategy': 'most_frequent', 'numeric_impute_strategy': 'mean', 'categorical_fill_value': None, 'numeric_fill_value': None}, 'Logistic Regression Classifier':{'penalty': 'l2', 'C': 1.0, 'n_jobs': -1, 'multi_class': 'auto', 'solver': 'lbfgs'}}, custom_hyperparameters={'None':{'sampling_ratio': 0.25}}, random_seed=0)

# %%
best_pipeline=automl.best_pipeline

# %% [markdown]
# ## Let's Check the detailed desscription

# %%
automl.describe_pipeline(automl.rankings.iloc[0]["id"])
# Out:
# ***************************************************************
# * Logistic Regression Classifier w/ Imputer + Standard Scaler *
# ***************************************************************
#
# Problem Type: binary
# Model Family: Linear
#
# Pipeline Steps
# ==============
# 1. Imputer
# 	 * categorical_impute_strategy : most_frequent
# 	 * numeric_impute_strategy : mean
# 	 * categorical_fill_value : None
# 	 * numeric_fill_value : None
# 2. Standard Scaler
# 3. Logistic Regression Classifier
# 	 * penalty : l2
# 	 * C : 1.0
# 	 * n_jobs : -1
# 	 * multi_class : auto
# 	 * solver : lbfgs
#
# Training
# ========
# Training for binary problems.
# Total training time (including CV): 21.6 seconds
#
# Cross Validation
# ----------------
#              Log Loss Binary  MCC Binary   AUC  Precision    F1  Balanced Accuracy Binary  Accuracy Binary  Sensitivity at Low Alert Rates # Training # Validation
# 0                      0.061       0.958 0.997      0.966 0.974                     0.981            0.980                           0.412        303          152
# 1                      0.128       0.930 0.984      0.981 0.955                     0.960            0.967                           0.333        303          152
# 2                      0.093       0.944 0.993      1.000 0.963                     0.964            0.974                           0.261        304          151
# mean                   0.094       0.944 0.991      0.982 0.964                     0.968            0.974                           0.335          -            -
# std                    0.034       0.014 0.006      0.017 0.010                     0.011            0.007                           0.075          -            -
# coef of var            0.359       0.015 0.007      0.018 0.010                     0.011            0.007                           0.225          -            -

# %%
### Evaluate on hold out data
best_pipeline.score(X_test, y_test, objectives=["auc","f1","Precision","Recall"])
# Out:
# OrderedDict([('AUC', 0.9933862433862434),
#              ('F1', 0.963855421686747),
#              ('Precision', 0.975609756097561),
#              ('Recall', 0.9523809523809523)])

# %% [markdown]
# ## We can also optimize for a problem specific objective

# %%
automl_auc = AutoMLSearch(X_train=X_train, y_train=y_train,
                          problem_type='binary',
                          objective='auc',
                          additional_objectives=['f1', 'precision'],
                          max_batches=1,
                          optimize_thresholds=True)

automl_auc.search()
# Out:
# Generating pipelines to search over...
# 8 pipelines ready for search.
#
# *****************************
# * Beginning pipeline search *
# *****************************
#
# Optimizing for AUC.
# Greater score is better.
#
# Using SequentialEngine to train and score pipelines.
# Searching up to 1 batches for a total of 9 pipelines.
# Allowed model families: decision_tree, linear_model, xgboost, extra_trees, catboost, random_forest, lightgbm
# FigureWidget({
#     'data': [{'mode': 'lines+markers',
#               'name': 'Best Score',
#               'type'…
# Evaluating Baseline Pipeline: Mode Baseline Binary Classification Pipeline
# Mode Baseline Binary Classification Pipeline:
# 	Starting cross validation
# 	Finished cross validation - mean AUC: 0.500
#
# *****************************
# * Evaluating Batch Number 1 *
# *****************************
#
# Elastic Net Classifier w/ Imputer + Standard Scaler:
# 	Starting cross validation
# 	Finished cross validation - mean AUC: 0.987
# Decision Tree Classifier w/ Imputer:
# 	Starting cross validation
# 	Finished cross validation - mean AUC: 0.923
# Random Forest Classifier w/ Imputer:
# 	Starting cross validation
# 	Finished cross validation - mean AUC: 0.992
# LightGBM Classifier w/ Imputer:
# 	Starting cross validation
# 	Finished cross validation - mean AUC: 0.991
# Logistic Regression Classifier w/ Imputer + Standard Scaler:
# 	Starting cross validation
# 	Finished cross validation - mean AUC: 0.991
# XGBoost Classifier w/ Imputer:
# 	Starting cross validation
# 	Finished cross validation - mean AUC: 0.991
# Extra Trees Classifier w/ Imputer:
# 	Starting cross validation
# 	Finished cross validation - mean AUC: 0.993
# CatBoost Classifier w/ Imputer:
# 	Starting cross validation
# 	Finished cross validation - mean AUC: 0.991
#
# Search finished after 00:55
# Best pipeline: Extra Trees Classifier w/ Imputer
# Best pipeline AUC: 0.992791

# %%
automl_auc.rankings
# Out:
#    id                                      pipeline_name  mean_cv_score  \
# 0   7                  Extra Trees Classifier w/ Imputer       0.992791
# 1   3                Random Forest Classifier w/ Imputer       0.992482
# 2   5  Logistic Regression Classifier w/ Imputer + St...       0.991342
# 3   8                     CatBoost Classifier w/ Imputer       0.991305
# 4   6                      XGBoost Classifier w/ Imputer       0.991265
# 5   4                     LightGBM Classifier w/ Imputer       0.990700
# 6   1  Elastic Net Classifier w/ Imputer + Standard S...       0.987268
# 7   2                Decision Tree Classifier w/ Imputer       0.923371
# 8   0       Mode Baseline Binary Classification Pipeline       0.500000
#
#    standard_deviation_cv_score  validation_score  \
# 0                     0.003920          0.995753
# 1                     0.003840          0.994367
# 2                     0.006489          0.996676
# 3                     0.003883          0.993906
# 4                     0.004012          0.995568
# 5                     0.001723          0.991505
# 6                     0.010092          0.994829
# 7                     0.018786          0.919298
# 8                     0.000000          0.500000
#
#    percent_better_than_baseline  high_variance_cv  \
# 0                     49.279119             False
# 1                     49.248175             False
# 2                     49.134239             False
# 3                     49.130502             False
# 4                     49.126544             False
# 5                     49.070044             False
# 6                     48.726751             False
# 7                     42.337093             False
# 8                      0.000000             False
#
#                                           parameters
# 0  {'Imputer': {'categorical_impute_strategy': 'm...
# 1  {'Imputer': {'categorical_impute_strategy': 'm...
# 2  {'Imputer': {'categorical_impute_strategy': 'm...
# 3  {'Imputer': {'categorical_impute_strategy': 'm...
# 4  {'Imputer': {'categorical_impute_strategy': 'm...
# 5  {'Imputer': {'categorical_impute_strategy': 'm...
# 6  {'Imputer': {'categorical_impute_strategy': 'm...
# 7  {'Imputer': {'categorical_impute_strategy': 'm...
# 8      {'Baseline Classifier': {'strategy': 'mode'}}

# %%
automl_auc.describe_pipeline(automl_auc.rankings.iloc[0]["id"])
# Out:
# *************************************
# * Extra Trees Classifier w/ Imputer *
# *************************************
#
# Problem Type: binary
# Model Family: Extra Trees
#
# Pipeline Steps
# ==============
# 1. Imputer
# 	 * categorical_impute_strategy : most_frequent
# 	 * numeric_impute_strategy : mean
# 	 * categorical_fill_value : None
# 	 * numeric_fill_value : None
# 2. Extra Trees Classifier
# 	 * n_estimators : 100
# 	 * max_features : auto
# 	 * max_depth : 6
# 	 * min_samples_split : 2
# 	 * min_weight_fraction_leaf : 0.0
# 	 * n_jobs : -1
#
# Training
# ========
# Training for binary problems.
# Total training time (including CV): 7.3 seconds
#
# Cross Validation
# ----------------
#               AUC    F1  Precision # Training # Validation
# 0           0.996 0.964      0.982        303          152
# 1           0.994 0.914      1.000        303          152
# 2           0.988 0.927      0.944        304          151
# mean        0.993 0.935      0.975          -            -
# std         0.004 0.026      0.028          -            -
# coef of var 0.004 0.028      0.029          -            -

# %%
best_pipeline_auc = automl_auc.best_pipeline

# %%
#get the score on holdout data
best_pipeline_auc.score(X_test, y_test,  objectives=["auc"])
# Out:
# OrderedDict([('AUC', 0.986111111111111)])

# %%
best_pipeline.save("model.pkl")

# %% [markdown]
# ## Loading the Model

# %%
check_model=automl.load('model.pkl')

# %%
check_model.predict_proba(X_test)
# Out:
#            benign  malignant
# 0    9.996252e-01   0.000375
# 1    9.845724e-01   0.015428
# 2    7.749595e-01   0.225040
# 3    9.907312e-01   0.009269
# 4    9.998272e-01   0.000173
# ..            ...        ...
# 109  9.990961e-01   0.000904
# 110  7.981366e-01   0.201863
# 111  9.999924e-01   0.000008
# 112  1.082727e-08   1.000000
# 113  9.999267e-01   0.000073
#
# [114 rows x 2 columns]
